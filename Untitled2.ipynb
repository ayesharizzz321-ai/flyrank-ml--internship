# %% [markdown]
# <a href="https://colab.research.google.com/github/ayesharizzz321-ai/flyrank-ml--internship/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 'your turn' cell mein yeh code run karein
print("My first ML pipeline discovery is complete!")
# Out:
# My first ML pipeline discovery is complete!
